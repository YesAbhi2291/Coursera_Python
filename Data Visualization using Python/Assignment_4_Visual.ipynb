# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

df=pd.read_csv('C:\\Users\\abhir\\OneDrive\\Desktop\\Data Science using Python\\GDP_Growth_Data\\gdp.csv')
df=df[0:8]
df
# Out:
#              Series Name        Series Code Country Name Country Code  \
# 0  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG  Afghanistan          AFG
# 1  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   Bangladesh          BGD
# 2  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG       Bhutan          BTN
# 3  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG        India          IND
# 4  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG     Maldives          MDV
# 5  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG        Nepal          NPL
# 6  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG     Pakistan          PAK
# 7  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG    Sri Lanka          LKA
#
#    2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 0      21.390528      14.362441       0.426355      12.752287       5.600745
# 1       5.045125       5.571802       6.464384       6.521435       6.013610
# 2       6.657224      11.730854       7.890914       5.071710       2.142497
# ...

# %%
df=df.drop(['Series Name','Series Code','Country Name'],axis=1)

# %%
df
# Out:
#   Country Code  2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# 0          AFG      21.390528      14.362441       0.426355      12.752287
# 1          BGD       5.045125       5.571802       6.464384       6.521435
# 2          BTN       6.657224      11.730854       7.890914       5.071710
# 3          IND       7.861889       8.497585       5.241345       5.456359
# 4          MDV      -7.228841       7.265129       8.566734       2.517384
# 5          NPL       4.533079       4.816415       3.421828       4.781192
# 6          PAK       2.831659       1.606689       2.748406       3.507033
# 7          LKA       3.538912       8.015967       8.404733       9.144572
#
#    2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  \
# 0       5.600745       2.724543       1.451315       2.260314       2.665292
# 1       6.013610       6.061059       6.552653       7.113489       7.284184
# ...

# %%
df.set_index('Country Code',inplace=True)

# %%
df
# Out:
#               2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# Country Code
# AFG               21.390528      14.362441       0.426355      12.752287
# BGD                5.045125       5.571802       6.464384       6.521435
# BTN                6.657224      11.730854       7.890914       5.071710
# IND                7.861889       8.497585       5.241345       5.456359
# MDV               -7.228841       7.265129       8.566734       2.517384
# NPL                4.533079       4.816415       3.421828       4.781192
# PAK                2.831659       1.606689       2.748406       3.507033
# LKA                3.538912       8.015967       8.404733       9.144572
#
#               2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# Country Code
# AFG                5.600745       2.724543       1.451315       2.260314
# BGD                6.013610       6.061059       6.552653       7.113489
# ...

# %%
df.columns
# Out:
# Index(['2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]',
#        '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]',
#        '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
a=[i.split('[', 1)[0] for i in df.columns]
j=[k.strip(' ') for k in a]
j
df.columns=j
    
df
# Out:
#                    2009       2010      2011       2012      2013      2014  \
# Country Code
# AFG           21.390528  14.362441  0.426355  12.752287  5.600745  2.724543
# BGD            5.045125   5.571802  6.464384   6.521435  6.013610  6.061059
# BTN            6.657224  11.730854  7.890914   5.071710  2.142497  5.745455
# IND            7.861889   8.497585  5.241345   5.456359  6.386106  7.410228
# MDV           -7.228841   7.265129  8.566734   2.517384  7.281074  7.329626
# NPL            4.533079   4.816415  3.421828   4.781192  4.128878  5.988985
# PAK            2.831659   1.606689  2.748406   3.507033  4.396457  4.674708
# LKA            3.538912   8.015967  8.404733   9.144572  3.395733  4.960701
#
#                   2015      2016      2017      2018
# Country Code
# AFG           1.451315  2.260314  2.665292  1.030660
# BGD           6.552653  7.113489  7.284184  7.863709
# BTN           6.644564  8.022101  4.629101  2.290648
# ...

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(df['2009'])
# Out:
# pandas.core.series.Series

# %%
plt.style.use('seaborn-colorblind')

df.plot(colormap='viridis',figsize=(10,5),lw=2)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
df=df.T
df
# Out:
# Country Code        AFG       BGD        BTN       IND       MDV       NPL  \
# 2009          21.390528  5.045125   6.657224  7.861889 -7.228841  4.533079
# 2010          14.362441  5.571802  11.730854  8.497585  7.265129  4.816415
# 2011           0.426355  6.464384   7.890914  5.241345  8.566734  3.421828
# 2012          12.752287  6.521435   5.071710  5.456359  2.517384  4.781192
# 2013           5.600745  6.013610   2.142497  6.386106  7.281074  4.128878
# 2014           2.724543  6.061059   5.745455  7.410228  7.329626  5.988985
# 2015           1.451315  6.552653   6.644564  7.996254  2.884549  3.322905
# 2016           2.260314  7.113489   8.022101  8.169527  6.338301  0.588678
# 2017           2.665292  7.284184   4.629101  7.167889  6.803666  8.223499
# 2018           1.030660  7.863709   2.290648  6.811369  6.888817  6.657533
#
# Country Code       PAK       LKA
# 2009          2.831659  3.538912
# 2010          1.606689  8.015967
# 2011          2.748406  8.404733
# ...

# %%
df.index
# Out:
# Index(['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018'],
#       dtype='object')

# %%
#plt.style.use('seaborn-colorblind')
df.plot(colormap='Set1',figsize=(10,5),lw=2,alpha=0.75);
plt.legend(loc=9,fontsize='small');
plt.gca().spines['right'].set_visible(False);
plt.gca().spines['top'].set_visible(False);
plt.gca().set_xlabel('Number of Years');
plt.gca().set_ylabel('GDP Growth(Annual %)');
plt.title('GDP Growth trend in South Asian countries from 2009-2018');
plt.gca().tick_params(axis='both',which='both',length=0)
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.gcf().savefig("Pic4.jpg",bbox_inches='tight')
